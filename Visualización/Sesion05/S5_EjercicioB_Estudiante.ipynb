# %% [markdown]
# # Modulo 8 — Sesion 5 · Ejercicio B
#
# | | |
# |---|---|
# | **Tipo** | Ejercicio B — Independiente |
# | **Tiempo** | 50 minutos |
# | **Producto esperado** | Score propio con 3-5 variables, pesos justificados, top 10 comparado |
#
# ### Objetivo
# El participante construye su propio modelo de score de riesgo eligiendo
# variables del dataset DIFERENTES a las del modelo base,
# justificando sus pesos con logica de negocio
# y comparando su top 10 con el del modelo del modulo.
#
# - No dar la respuesta directamente — hacer preguntas: *"¿Por que le diste ese peso?"*
# - No hay respuesta correcta unica — evaluar la coherencia logica
# - Recordar: los pesos DEBEN sumar exactamente 1.0
# - Pregunta de cierre: *"¿Cambia el top 10 cuando usas tus variables?"*

# %% [markdown]
# ## ✏️ TU TURNO — Score personalizado con variables propias
#
# **Reglas:**
# - Usa variables DIFERENTES a las del modelo base
# - Los pesos deben sumar exactamente 1.0
# - Cada variable necesita una justificacion de negocio

# %%
import pandas as pd
import numpy as np
import plotly.express as px

df = pd.read_csv('hr_ibm.csv')

# Modelo base del modulo (referencia para comparar al final)

# %%
# PASO 1 — DEFINIR TUS VARIABLES Y PESOS
# Elige entre 3 y 5 variables DIFERENTES a las del modelo base
# Variables base (NO usar): OverTime, JobSatisfaction, YearsAtCompany,
#                           WorkLifeBalance, EnvironmentSatisfaction

# %%
# PASO 2 — IMPLEMENTAR LA FUNCION DE SCORE PERSONALIZADO

# %%
# PASO 3 — COMPARAR TOP 10 CON EL MODELO BASE DEL MODULO


# Grafica de comparacion de scores

# %%
# PASO 4 — PREGUNTAS DE ANALISIS
# Responde en las celdas de texto (Markdown) siguientes

print("Preguntas de analisis:")
print()
print("1. ¿Por que elegiste esas variables y no otras?")
print("   Menciona la logica de negocio de al menos 2 de ellas.")
print()
print("2. ¿Cambio el top 10 respecto al modelo base?")
print(f"   Coincidencias encontradas: {coinciden}/10")
print("   ¿A que atribuyes las diferencias?")
print()
print("3. Si tuvieras que defender tu modelo frente al Director de RH,")
print("   ¿como justificarias la distribucion de pesos que elegiste?")

# %% [markdown]
# ### Responde aqui:
#
# **Pregunta 1:** ¿Por que elegiste esas variables?
#
# *Tu respuesta:*
#
# ---
#
# **Pregunta 2:** ¿Cambio el top 10? ¿A que lo atribuyes?
#
# *Tu respuesta:*
#
# ---
#
# **Pregunta 3:** ¿Como defiendes tu distribucion de pesos frente al Director?
#
# *Tu respuesta:*
