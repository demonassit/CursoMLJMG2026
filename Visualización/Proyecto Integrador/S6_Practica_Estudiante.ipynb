# %% [markdown]
# # Modulo 8 -- Sesion 6 · Practica Integradora
# ## Cuadernillo del ESTUDIANTE -- Storytelling con datos
#
# | | |
# |---|---|
# | **Modulo** | 8 -- Visualizacion de datos para la toma de decisiones |
# | **Sesion** | 6 -- Storytelling con datos y presentacion ejecutiva |
# | **Punto de partida** | Tu dashboard publicado de la Sesion 5 |
#
# ---
#
# ### Objetivo de esta sesion
#
# Al terminar esta sesion tendras:
# 1. Las graficas de tu dashboard con anotaciones que el Director puede entender sin explicacion
# 2. Una pestana de conclusiones que se actualiza con los filtros
# 3. Un documento Word de informe ejecutivo -- tu entregable escrito final
# 4. Un guion de 5 minutos para presentar tus hallazgos
#
# ### Como usar este cuadernillo
#
# | Tipo | Que hacer |
# |------|-----------|
# | Celdas **▶ EJECUTA** | Correr sin modificar |
# | Celdas **✏️ TU TURNO** | Completar o adaptar |
# | Celdas de reflexion | Escribir tu respuesta en Markdown |

# %% [markdown]
# ### C1 -- ▶ EJECUTA -- Diagnostico de tu dashboard
# **¿Tu dashboard comunica o solo muestra datos?**
#
# Antes de agregar anotaciones, necesitas saber exactamente
# que cambiar. Ejecuta la celda y responde las preguntas.

# %%
# Abre tu dashboard publicado y responde estas preguntas en la celda de texto abajo.
# No hay codigo que ejecutar -- este es un ejercicio de analisis critico.

preguntas_diagnostico = [
    "1. ¿Que titulo de grafica no entenderia el Director sin contexto?",
    "2. ¿Que KPI no tiene unidades claras o significado explicito?",
    "3. ¿En que parte del dashboard el director tendria que 'explorar' en lugar de 'leer'?",
    "4. ¿Hay algun numero sin comparacion? (16 % de rotacion... ¿vs que?)",
    "5. ¿La pestana de riesgo responde 'quien se va' o solo muestra datos?",
]

for p in preguntas_diagnostico:
    print(p)

# %% [markdown]
# **Reflexion -- responde aqui (edita esta celda):**
#
# 1. Elemento que el Director no entenderia sin contexto: ___________
# 2. KPI sin unidades o significado claro: ___________
# 3. Parte donde el director tiene que 'explorar' en lugar de 'leer': ___________

# %% [markdown]
# ### C2 -- ▶ EJECUTA + ✏️ TU TURNO -- Anotaciones en la grafica de barras
# Primero ejecuta la grafica sin anotaciones. Luego ejecuta la version con anotaciones.
# ¿Notas la diferencia desde la perspectiva del Director?

# %%
import pandas as pd
import plotly.express as px

# Cargar el dataset
df = pd.read_csv('hr_ibm.csv')

# Calcular tasa de rotacion por departamento

# %%
# Grafica de barras SIN anotaciones -- version original

# %%
# Grafica de barras CON anotaciones -- version storytelling


# 1. Linea de referencia -- estandar del sector (10 %)


# 2. Anotacion sobre la barra del departamento critico

# %% [markdown]
# **✏️ TU TURNO -- integra en tu app.py:**
#
# Copia la funcion `grafica_rotacion_con_anotaciones()` de la celda siguiente
# en tu app.py y reemplaza tu funcion `grafica_rotacion` existente.

# %%
# Version para integrar en el server() de la app Shiny
# (reemplaza el cuerpo de tu funcion grafica_rotacion existente)

# %% [markdown]
# ### C3 -- ▶ EJECUTA + ✏️ TU TURNO -- Anotaciones en el scatter
# Agrega la zona de riesgo alto y la linea de salario promedio para crear 4 cuadrantes.

# %%
# Primero necesitamos calcular el score de riesgo
# (si ya tienes la funcion calcular_score de S5, importala aqui)

# %%
# Scatter CON anotaciones -- version storytelling

# %% [markdown]
# **✏️ TU TURNO -- integra en tu app.py:**
#
# Copia la funcion `grafica_scatter_con_cuadrantes()` de la celda siguiente
# y reemplaza tu funcion `grafica_riesgo_scatter` existente.

# %%
# Version para integrar en el server() de la app Shiny
# (reemplaza o extiende tu funcion grafica_riesgo_scatter existente)

# %% [markdown]
# ### C4 -- ▶ EJECUTA -- Pestana de conclusiones reactiva
# Las 4 secciones del resumen ejecutivo que se actualizan con los filtros.

# %%
# Funciones auxiliares para la pestana de conclusiones
# (definir fuera del server, antes de def server())


# Prueba con el dataset completo
from IPython.display import HTML
HTML(html_resumen_ejecutivo(df, df_score))

# %% [markdown]
# **✏️ TU TURNO -- integra en tu app.py:**
#
# Copia los comentarios de la celda siguiente para agregar la pestana de conclusiones.

# %%
# Codigo completo para integrar en la app Shiny
# Agrega esta pestana al navbarPage (cuarta pestana):

# En el ui:
# ui.nav_panel('Conclusiones',
#     ui.h4('Resumen ejecutivo -- TechNova Solutions'),
#     ui.output_ui('seccion_resumen'),
#     ui.output_ui('seccion_hallazgos'),
#     ui.output_ui('seccion_top3'),
#     ui.output_ui('seccion_recomendacion'),
# ),

# En el server:
# @render.ui
# def seccion_resumen():
#     return ui.HTML(html_resumen_ejecutivo(datos_filtrados(), datos_con_score()))
#
# @render.ui
# def seccion_hallazgos():
#     return ui.HTML(html_hallazgos_clave(datos_filtrados(), datos_con_score()))
#
# @render.ui
# def seccion_top3():
#     return ui.HTML(html_empleados_prioritarios(datos_con_score()))
#
# @render.ui
# def seccion_recomendacion():
#     return ui.HTML(html_recomendacion(datos_filtrados(), datos_con_score()))

print("Codigo de integracion mostrado en los comentarios de arriba.")
print("Copia las secciones correspondientes en tu app.py.")

# %% [markdown]
# ### C5 -- ✏️ TU TURNO -- Guion de 5 minutos
# Calcula los numeros reales de tu dashboard y llena el guion.

# %%
# Generar los numeros reales de tu dashboard para llenar el guion
import pandas as pd
df = pd.read_csv('hr_ibm.csv')

# Los calculos del guion

# %%
# GUION DE 5 MINUTOS -- completa los espacios con los numeros de arriba

guion = f"""
GUION DE PRESENTACION -- DASHBOARD TECHNOVA
Tiempo total: 5 minutos

--- MIN 1: CONTEXTO (30 segundos) ---
'El dataset de TechNova tiene {total:,} colaboradores.
La tasa de rotacion actual es del {tasa_global:.1f} %.
Eso representa {rotaron} personas reales que dejaron la empresa.'

--- MIN 2: HALLAZGO 1 (90 segundos) ---
'El departamento con mayor rotacion es {depto_critico} con una tasa del {tasa_critica:.1f} %.
Eso es {ratio_critico:.1f} veces mayor que el promedio del resto de departamentos.
La linea de referencia en la grafica muestra que estamos {tasa_critica - 10:.1f} puntos
por encima del estandar del sector del 10 %.'

--- MIN 3: HALLAZGO 2 (90 segundos) ---
'Los empleados con horas extra tienen {ratio_ot:.1f} veces mayor probabilidad de renunciar.
En el scatter puede ver que los puntos rojos se concentran en la zona de alta carga laboral.
El cuadrante de maxima prioridad: riesgo alto con salario alto.'

--- MIN 4: RIESGO (30 segundos) ---
'En la pestana de Riesgo estan los 10 empleados con mayor probabilidad de renunciar.
Los 3 primeros son [PUESTO 1], [PUESTO 2] y [PUESTO 3].'

--- MIN 5: RECOMENDACION (30 segundos) ---
'Mi recomendacion: revision de condiciones de horas extra en {depto_critico}.
Una conversacion de retencion con los 3 primeros del ranking podria evitar
${costo_renuncia * 3:,.0f} en costos de contratacion.'
"""

print(guion)

# %% [markdown]
# **Practica en voz alta:**
# Lee el guion completo en voz alta una vez -- cronometra.
# ¿Cuanto tiempo te tomo? ¿Que parte no quedaba clara al escucharla?
#
# *Notas del ensayo:* _______________________________________________

# %% [markdown]
# ### C6 -- ✏️ TU TURNO -- Documento Word de conclusiones (Ejercicio B)
# **Tipo:** Tarea independiente  |  **Tiempo:** 50 min
#
# **Instrucciones:**
# Genera el documento Word de tus conclusiones usando los 4 actos narrativos
# como estructura. Este documento es tu informe ejecutivo para el Director de RH
# -- redactalo en lenguaje de negocios, sin terminos tecnicos.
#
# **Requisitos:**
# - Estructura de 4 actos: contexto / hallazgo / riesgo / recomendacion
# - Numeros reales de tu dashboard (no ejemplos genericos)
# - Lenguaje ejecutivo: di "empleados en riesgo de renuncia" no "score alto"
# - La recomendacion debe incluir el costo estimado de no actuar
# - Maximo 2 paginas

# %%
# Instalacion de python-docx si no esta disponible
# (ejecutar solo si da error de importacion)
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', 'python-docx',
                '--break-system-packages', '-q'])
print("python-docx disponible")

# %%
from docx import Document
from docx.shared import Pt, RGBColor, Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH
import pandas as pd

# Cargar el dataset para calcular los numeros reales
df = pd.read_csv('hr_ibm.csv')

# ── Calculos base ────────────────────────────────────────────

# %%
# ── Generar el documento Word ────────────────────────────────


# Estilos basicos


# Funcion auxiliar para agregar parrafos con estilo




# ── ENCABEZADO ────────────────────────────────────────────────


# ── ACTO 1: CONTEXTO ─────────────────────────────────────────


# ── ACTO 2: HALLAZGO ──────────────────────────────────────────


# ── ACTO 3: RIESGO ────────────────────────────────────────────




# ── ACTO 4: RECOMENDACION ────────────────────────────────────




# ── GUARDAR ───────────────────────────────────────────────────

# %% [markdown]
# **✏️ Personaliza el documento:**
#
# El codigo anterior genera una version base con los numeros del dataset.
# Revisa el archivo Word generado y:
# 1. Reemplaza los valores entre corchetes [PUESTO 1], etc.
# 2. Agrega contexto especifico de tu analisis
# 3. Ajusta la recomendacion con tu propia perspectiva
# 4. Verifica que no hay terminos tecnicos (sin 'DataFrame', 'score', 'reactive')

# %% [markdown]
# ---
# ### Autoevaluacion
#
# | Criterio | Cumple |
# |----------|--------|
# | La grafica de barras tiene linea de referencia en 10 % | ☐ |
# | La grafica de barras tiene anotacion sobre la barra critica | ☐ |
# | El scatter tiene zona sombreada de riesgo alto (score > 70) | ☐ |
# | El scatter tiene linea vertical del salario promedio | ☐ |
# | La pestana de conclusiones esta integrada en el dashboard | ☐ |
# | La pestana de conclusiones se actualiza al cambiar filtros | ☐ |
# | El documento Word tiene los 4 actos narrativos | ☐ |
# | El documento Word usa lenguaje ejecutivo (sin terminos tecnicos) | ☐ |
# | El guion de 5 minutos fue ensayado en voz alta | ☐ |
# | La recomendacion incluye un costo estimado de no actuar | ☐ |
